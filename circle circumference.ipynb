# %% [markdown]
# ## Circle circunference calculater                                              Assignment # 2

# %% [markdown]
# <img src ="data:image/jpeg;base64,..." />

# %%
Radius=float(input("circle redius is ="))
Circle_circumference=2*Radius*3.14
print ("circle circumference is" , Circle_circumference )

# %% [markdown]
# ## Thanks
# ## Nashwa Elsawaf
